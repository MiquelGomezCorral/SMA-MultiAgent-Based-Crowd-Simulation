# %% [markdown]
# # INITIAL CONFIGURATION

# %%
import os

print(os.getcwd())
if not os.getcwd().endswith("app"):
    os.chdir("../app")
    print(os.getcwd())

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /home/turbotowerlnx/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.config import Configuration

CONFIG = Configuration(
    n_agents=1,
    width=10,
    height=10,
    agent_types_ratios = {
        "polite": 0.7,
        "aggressive": 0.2,
        "slow": 0.1
    },
)

# %% [markdown]
# # CROWD MODEL

# %% [markdown]
# ### Render

# %%
model_params = {
    "n_agents": {
        "type": "SliderInt",
        "value": 50,
        "label": "Number of agents:",
        "min": 10,
        "max": 200,
        "step": 1,
    },
    "width": {
        "type": "SliderInt",
        "value": 10,
        "label": "Grid width:",
        "min": 5,
        "max": 50,
        "step": 1,
    },
    "height": {
        "type": "SliderInt",
        "value": 10,
        "label": "Grid height:",
        "min": 5,
        "max": 50,
        "step": 1,
    },
    "polite_ratio": {
        "type": "SliderFloat",
        "value": 0.7,
        "label": "Polite ratio:",
        "min": 0.0,
        "max": 1.0,
        "step": 0.1,
    },
    "aggressive_ratio": {
        "type": "SliderFloat",
        "value": 0.2,
        "label": "Aggressive ratio:",
        "min": 0.0,
        "max": 1.0,
        "step": 0.1,
    },
    "slow_ratio": {
        "type": "SliderFloat",
        "value": 0.1,
        "label": "Slow ratio:",
        "min": 0.0,
        "max": 1.0,
        "step": 0.1,
    },
}

# %%
from src.models import create_page, CrowdModelWrapper

# Create the initial model
crowd_model = CrowdModelWrapper(n_agents=10, width=10, height=10)

# Create and display the page
page = create_page(crowd_model, model_params)
page
# Out:
# Cannot show ipywidgets in text
