# %% [markdown]
# # INITIAL CONFIGURATION

# %%
import os

print(os.getcwd())
if not os.getcwd().endswith("app"):
    os.chdir("../app")
    print(os.getcwd())

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# /home/turbotowerlnx/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/notebooks
# /home/turbotowerlnx/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app

# %%
from src.config import Configuration

CONFIG = Configuration(
    n_experiments=1000,
    initial_agents=60,
    width=30,
    height=30,
    agent_types_ratios = {
        "polite": 0.5,
        "aggressive": 0.3,
        "slow": 0.2
    },
    track_last_steps=4,
    path_finding_algorithm="A*",
    differentiate_exits=True,
    respawn_agents=True,
    scenario_type="MALL",
    n_exits=4,
)

# %% [markdown]
# # CROWD MODEL

# %%
from src.models import create_page, CrowdModelWrapper, CrowdModel
from src.definitions import basic_model_params

# Create the initial model
crowd_model = CrowdModelWrapper(
    initial_agents=CONFIG.initial_agents,
    width=CONFIG.width,
    height=CONFIG.height,
    track_last_steps=CONFIG.track_last_steps,
    path_finding_algorithm=CONFIG.path_finding_algorithm,
    differentiate_exits=CONFIG.differentiate_exits,
    polite_ratio=CONFIG.agent_types_ratios["polite"],
    aggressive_ratio=CONFIG.agent_types_ratios["aggressive"],
    slow_ratio=CONFIG.agent_types_ratios["slow"],
    scenario_type=CONFIG.scenario_type,
    n_exits=CONFIG.n_exits,
    seed=CONFIG.seed,
    respawn_agents=CONFIG.respawn_agents,
)

# Create and display the page
page = create_page(crowd_model, basic_model_params)
page
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 from src.definitions import basic_model_params
#       4 # Create the initial model
# ----> 5 crowd_model = CrowdModelWrapper(
#       6     initial_agents=CONFIG.initial_agents,
#       7     width=CONFIG.width,
#       8     height=CONFIG.height,
#       9     track_last_steps=CONFIG.track_last_steps,
#      10     path_finding_algorithm=CONFIG.path_finding_algorithm,
#      11     differentiate_exits=CONFIG.differentiate_exits,
#      12     polite_ratio=CONFIG.agent_types_ratios["polite"],
#      13     aggressive_ratio=CONFIG.agent_types_ratios["aggressive"],
#      14     slow_ratio=CONFIG.agent_types_ratios["slow"],
#      15     scenario_type=CONFIG.scenario_type,
#      16     n_exits=CONFIG.n_exits,
#      17     seed=CONFIG.seed,
#      18     respawn_agents=CONFIG.respawn_agents,
#      19 )
#      21 # Create and display the page
#      22 page = create_page(crowd_model, basic_model_params)
#
# File ~/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app/src/models/crowd_model.py:382, in CrowdModelWrapper.__init__(self, initial_agents, width, height, seed, polite_ratio, aggressive_ratio, slow_ratio, track_last_steps, path_finding_algorithm, scenario_type, n_exits, differentiate_exits, respawn_agents)
#     349 def __init__(
#     350     self,
#     351     initial_agents=50,
#    (...)    363     respawn_agents=False,
#     364 ):
#     365     config = Configuration(
#     366         initial_agents=initial_agents,
#     367         width=width,
#    (...)    380         respawn_agents=respawn_agents,
#     381     )
# --> 382     super().__init__(config)
#
# File ~/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app/src/models/crowd_model.py:58, in CrowdModel.__init__(self, CONFIG)
#      56 self._create_walls()
#      57 self._create_exits()
# ---> 58 self._create_agents()
#      60 # ========== CREATE COLLECTORS ==========
#      61 self.datacollector = DataCollector(
#      62     model_reporters={
#      63         "total_agents": lambda m: m.current_agents,
#    (...)     87     agent_reporters={},
#      88 )
#
# File ~/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app/src/models/crowd_model.py:167, in CrowdModel._create_agents(self)
#     165 # =================== AGENT CREATION ===================
#     166 for agent_type, n_type_agents in agent_counts.items():
# --> 167     agents = CrowdAgent.create_agents(
#     168         self,
#     169         n_type_agents,
#     170         agent_type = agent_type,
#     171         track_last_steps = self.track_last_steps,
#     172         number_of_exits = self.n_exits if self.differentiate_exits else None,
#     173         respawn = self.respawn_agents,
#     174     )
#     175     if agent_type == CrowdAgentEnum.AGGRESSIVE:
#     176         self.priority_agents.extend(agents)
#
# File ~/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/venv/lib/python3.12/site-packages/mesa/agent.py:133, in Agent.create_agents(cls, model, n, *args, **kwargs)
#     131     instance_args = [arg[i] for arg in listlike_args]
#     132     instance_kwargs = {k: v[i] for k, v in listlike_kwargs.items()}
# --> 133     agent = cls(model, *instance_args, **instance_kwargs)
#     134     agents.append(agent)
#     135 return AgentSet(agents, random=model.random)
#
# File ~/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app/src/models/crowd_agents.py:37, in CrowdAgent.__init__(self, model, agent_type, track_last_steps, number_of_exits, respawn)
#      34 self.dead_lock_factor = CROWD_AGENT_STATS[agent_type]["dead_lock_factor"]
#      35 self.max_dead_lock_counter = CROWD_AGENT_STATS[agent_type]["max_dead_lock_counter"]
# ---> 37 self._reset_agent_state()
#
# File ~/Documents/Master/SMA/SMA-MultiAgent-Based-Crowd-Simulation/app/src/models/crowd_agents.py:226, in CrowdAgent._reset_agent_state(self)
#     224 """Reset agent tracking variables after respawning."""
#     225 self.cells_moved = 0
# --> 226 self.cells_moved_last_steps = [0] * len(self.cells_moved_last_steps)
#     227 self.dead_lock_counter = 0
#
# AttributeError: 'CrowdAgent' object has no attribute 'cells_moved_last_steps'

# %% [markdown]
# ### Batch Run

# %% [markdown]
# ### Alternative: Multiprocessing-safe batch run
# If you need multiple processes, disable autoreload first and restart the kernel:

# %%
CONFIGS =[
    Configuration(
        n_experiments=1000,
        initial_agents=250,
        width=30,
        height=30,
        agent_types_ratios = {
            "polite": 0.5,
            "aggressive": 0.3,
            "slow": 0.2
        },
        track_last_steps=4,
        path_finding_algorithm="A*",
        differentiate_exits=False,
        scenario_type="SNAKE",
        n_exits=1,
    ),
    Configuration(
        n_experiments=1000,
        initial_agents=250,
        width=30,
        height=30,
        agent_types_ratios = {
            "polite": 0.5,
            "aggressive": 0.3,
            "slow": 0.2
        },
        track_last_steps=4,
        path_finding_algorithm="BFS",
        differentiate_exits=False,
        scenario_type="SNAKE",
        n_exits=1,
    ),
    Configuration(
        n_experiments=1000,
        initial_agents=250,
        width=30,
        height=30,
        agent_types_ratios = {
            "polite": 0.5,
            "aggressive": 0.3,
            "slow": 0.2
        },
        track_last_steps=4,
        path_finding_algorithm="MANHATTAN",
        differentiate_exits=False,
        scenario_type="SNAKE",
        n_exits=1,
    ),
]

# %%
# import mesa 
# import sys
# import numpy as np
# import pandas as pd

# from maikol_utils.print_utils import print_separator, print_color

# for idx, CONFIG in enumerate(CONFIGS):
#     print_separator(f"Running configuration {idx + 1}/{len(CONFIGS)}", sep_type="START")
#     rng = np.random.default_rng(CONFIG.seed)
#     seed_values = rng.integers(0, sys.maxsize, size=(CONFIG.n_experiments,))

#     # Create batch parameters from the current CONFIG
#     batch_params = {
#         "initial_agents": CONFIG.initial_agents,
#         "width": CONFIG.width,
#         "height": CONFIG.height,
#         "track_last_steps": CONFIG.track_last_steps,
#         "path_finding_algorithm": CONFIG.path_finding_algorithm,
#         "differentiate_exits": CONFIG.differentiate_exits,
#         "polite_ratio": CONFIG.agent_types_ratios["polite"],
#         "aggressive_ratio": CONFIG.agent_types_ratios["aggressive"],
#         "slow_ratio": CONFIG.agent_types_ratios["slow"],
#         "scenario_type": CONFIG.scenario_type,
#         "n_exits": CONFIG.n_exits,
#     }

#     results = mesa.batch_run(
#         model_cls=CrowdModelWrapper,
#         parameters=batch_params,
#         rng=seed_values.tolist(),
#         max_steps=2000,
#         number_processes=16,
#         data_collection_period=1,
#         display_progress=True,
#     )
#     # len(results)
#     results_df = pd.DataFrame(results)
#     results_df.groupby(['RunId', 'iteration'])["Step"].max().describe()
#     print_color(f"Results for configuration {idx + 1}:", color="cyan")

#     print(results_df.groupby(['RunId', 'iteration'])["Step"].max().describe())

# %%
results_df.groupby(['RunId', 'iteration'])["macro_average_speed"].max().describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 results_df.groupby(['RunId', 'iteration'])["macro_average_speed"].max().describe()
#
# NameError: name 'results_df' is not defined

# %% [markdown]
# ```
# count    10000.000000
# mean         0.824213
# std          0.033114
# min          0.726998
# 25%          0.800000
# 50%          0.820000
# 75%          0.840000
# max          0.980000
# Name: macro_average_speed, dtype: float64
# ```
